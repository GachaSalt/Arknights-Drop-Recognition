# %%
from core import FullStream
from core.fileHandle import  *
from core.plot import plot, show

example = FullStream('test.png')
example.print()
# Out:
# STAGE: 1-7
# STAR: 3
# STATUS: ['正常']
# LV: 89
# EXP: 2080
# ITEMS:
# {'id': 'FURN', 'count': None, 'name': '家具', 'success': True}
# {'id': '3003', 'count': '1', 'name': '赤金', 'success': True}
# {'id': '2001', 'count': '1', 'name': '基础作战记录', 'success': True}
# {'id': 'randomMaterial_1', 'count': '1', 'name': '罗德岛物资补给', 'success': True}
# {'id': '30012', 'count': '1', 'name': '固源岩', 'success': True}

# %%
show(example.raw)

# %%
example.data.plot_all()
